# %%
import json
import gzip
import pandas as pd
import datetime
# !pip install transformers
from transformers import pipeline
from google.colab import drive
drive.mount('/content/drive')
import numpy as np
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.6)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Load Data

# %%
# load user reviews data for beauty category
file = '/content/drive/MyDrive/CS 229 Group Project/Data/All_Beauty.jsonl.gz'

data_list = []

with gzip.open(file, 'rt', encoding='utf-8') as fp:
    for line in fp:
        data = json.loads(line.strip())
        data_list.append(data)

Beauty_User_df = pd.DataFrame(data_list)

# %%
Beauty_User_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 701528 entries, 0 to 701527
# Data columns (total 10 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   rating             701528 non-null  float64
#  1   title              701528 non-null  object
#  2   text               701528 non-null  object
#  3   images             701528 non-null  object
#  4   asin               701528 non-null  object
#  5   parent_asin        701528 non-null  object
#  6   user_id            701528 non-null  object
#  7   timestamp          701528 non-null  int64
#  8   helpful_vote       701528 non-null  int64
#  9   verified_purchase  701528 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(6)
# memory usage: 48.8+ MB

# %%
# load user reviews data for fashion category
file = '/content/drive/MyDrive/CS 229 Group Project/Data/Amazon_Fashion.jsonl.gz'

data_list = []

with gzip.open(file, 'rt', encoding='utf-8') as fp:
    for line in fp:
        data = json.loads(line.strip())
        data_list.append(data)

Fashion_User_df = pd.DataFrame(data_list)

# %%
Fashion_User_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500939 entries, 0 to 2500938
# Data columns (total 10 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   rating             float64
#  1   title              object
#  2   text               object
#  3   images             object
#  4   asin               object
#  5   parent_asin        object
#  6   user_id            object
#  7   timestamp          int64
#  8   helpful_vote       int64
#  9   verified_purchase  bool
# dtypes: bool(1), float64(1), int64(2), object(6)
# memory usage: 174.1+ MB

# %%
# check user overlap between fashion and beauty categories
print(len(set(Beauty_User_df['user_id']).intersection(set(Fashion_User_df['user_id']))))
# Out:
# 116428

# %%
# load meta data for these 2 cateogories
file = '/content/drive/MyDrive/CS 229 Group Project/Data/meta_All_Beauty.jsonl.gz'

data_list = []

with gzip.open(file, 'rt', encoding='utf-8') as fp:
    for line in fp:
        data = json.loads(line.strip())
        data_list.append(data)

Meta_Beauty_df = pd.DataFrame(data_list)

# %%
Meta_Beauty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112590 entries, 0 to 112589
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   main_category    112590 non-null  object
#  1   title            112590 non-null  object
#  2   average_rating   112590 non-null  float64
#  3   rating_number    112590 non-null  int64
#  4   features         112590 non-null  object
#  5   description      112590 non-null  object
#  6   price            17704 non-null   float64
#  7   images           112590 non-null  object
#  8   videos           112590 non-null  object
#  9   store            101259 non-null  object
#  10  categories       112590 non-null  object
#  11  details          112590 non-null  object
#  12  parent_asin      112590 non-null  object
#  13  bought_together  0 non-null       object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 12.0+ MB

# %%
# load meta data for these 2 cateogories
file = '/content/drive/MyDrive/CS 229 Group Project/Data/meta_Amazon_Fashion.jsonl.gz'

data_list = []

with gzip.open(file, 'rt', encoding='utf-8') as fp:
    for line in fp:
        data = json.loads(line.strip())
        data_list.append(data)

Meta_Fashion_df = pd.DataFrame(data_list)

# %%
Meta_Fashion_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 826108 entries, 0 to 826107
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   main_category    826108 non-null  object
#  1   title            826108 non-null  object
#  2   average_rating   826108 non-null  float64
#  3   rating_number    826108 non-null  int64
#  4   features         826108 non-null  object
#  5   description      826108 non-null  object
#  6   price            50249 non-null   float64
#  7   images           826108 non-null  object
#  8   videos           826108 non-null  object
#  9   store            799270 non-null  object
#  10  categories       826108 non-null  object
#  11  details          826108 non-null  object
#  12  parent_asin      826108 non-null  object
#  13  bought_together  0 non-null       object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 88.2+ MB

# %% [markdown]
# User Review Data Analysis

# %%
beauty_users = set(Beauty_User_df['user_id'])
fashion_users = set(Fashion_User_df['user_id'])

overlapping_users = beauty_users.intersection(fashion_users)

Overlapping_User_Fashion_df = Fashion_User_df[Fashion_User_df['user_id'].isin(overlapping_users)]

# %%
print(len(beauty_users))
# Out:
# 631986

# %%
Overlapping_User_Fashion_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 210011 entries, 1 to 2500715
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   rating             210011 non-null  float64
#  1   title              210011 non-null  object
#  2   text               210011 non-null  object
#  3   images             210011 non-null  object
#  4   asin               210011 non-null  object
#  5   parent_asin        210011 non-null  object
#  6   user_id            210011 non-null  object
#  7   timestamp          210011 non-null  int64
#  8   helpful_vote       210011 non-null  int64
#  9   verified_purchase  210011 non-null  bool
#  10  datetime           210011 non-null  object
# dtypes: bool(1), float64(1), int64(2), object(7)
# memory usage: 17.8+ MB

# %%
print(len(set(Overlapping_User_Fashion_df['user_id'])))
# Out:
# 116428

# %% [markdown]
# # Slice User Review Data (focus on P5Y 2018-1-1 ~ 2023-9-11)

# %%
# Convert UNIX Timestamps to Datetime
# timestamps are in milliseconds:
Beauty_User_df['datetime'] = pd.to_datetime(Beauty_User_df['timestamp'], unit='ms')
Beauty_User_df['datetime'] = Beauty_User_df['datetime'].dt.date

Overlapping_User_Fashion_df['datetime'] = pd.to_datetime(Overlapping_User_Fashion_df['timestamp'], unit='ms')
Overlapping_User_Fashion_df['datetime'] = Overlapping_User_Fashion_df['datetime'].dt.date
# Out:
# <ipython-input-36-11fa550e9b85>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Overlapping_User_Fashion_df['datetime'] = pd.to_datetime(Overlapping_User_Fashion_df['timestamp'], unit='ms')
# <ipython-input-36-11fa550e9b85>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Overlapping_User_Fashion_df['datetime'] = Overlapping_User_Fashion_df['datetime'].dt.date

# %%
earliest_date = Overlapping_User_Fashion_df['datetime'].min()
latest_date = Overlapping_User_Fashion_df['datetime'].max()

print("Earliest date in data:", earliest_date)
print("Latest date in data:", latest_date)
# Out:
# Earliest date in data: 2004-11-23
# Latest date in data: 2023-08-27

# %%
earliest_date = Beauty_User_df['datetime'].min()
latest_date = Beauty_User_df['datetime'].max()

print("Earliest date in data:", earliest_date)
print("Latest date in data:", latest_date)
# Out:
# Earliest date in data: 2000-11-01
# Latest date in data: 2023-09-09

# %%
# only keep P10Y data
threshold_date = datetime.date(2018, 1, 1)
P5Y_Overlapping_User_Fashion_df = Overlapping_User_Fashion_df[Overlapping_User_Fashion_df['datetime'] >= threshold_date]

# %%
P5Y_Overlapping_User_Fashion_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 136241 entries, 1 to 2500594
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   rating             136241 non-null  float64
#  1   title              136241 non-null  object
#  2   text               136241 non-null  object
#  3   images             136241 non-null  object
#  4   asin               136241 non-null  object
#  5   parent_asin        136241 non-null  object
#  6   user_id            136241 non-null  object
#  7   timestamp          136241 non-null  int64
#  8   helpful_vote       136241 non-null  int64
#  9   verified_purchase  136241 non-null  bool
#  10  datetime           136241 non-null  object
# dtypes: bool(1), float64(1), int64(2), object(7)
# memory usage: 11.6+ MB

# %%
# check how many unique products in fashion category in this dataset
print(len(set(P5Y_Overlapping_User_Fashion_df['parent_asin'])))
# Out:
# 102339

# %% [markdown]
# ## save P5Y_Overlapping_User_Fashion_df

# %%
# save data
P5Y_Overlapping_User_Fashion_df.to_csv('/content/drive/MyDrive/CS 229 Group Project/Data/P5Y_Overlapping_User_Fashion_df.csv', index=False)

# %% [markdown]
# Meta Product Data Analysis

# %%
# check product overlap between two categories
print(len(set(Meta_Beauty_df['parent_asin']).intersection(set(Meta_Fashion_df['parent_asin']))))
# Out:
# 0

# %%
# slice top 1000 mostly reviewed products in beauty category
beauty_sorted_df = Meta_Beauty_df.sort_values(by='rating_number', ascending=False)

top_1000_beauty_df = beauty_sorted_df.head(1000)
top_50_beauty_df = beauty_sorted_df.head(50)

# %%
top_1000_beauty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 50834 to 47260
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   main_category    1000 non-null   object
#  1   title            1000 non-null   object
#  2   average_rating   1000 non-null   float64
#  3   rating_number    1000 non-null   int64
#  4   features         1000 non-null   object
#  5   description      1000 non-null   object
#  6   price            486 non-null    float64
#  7   images           1000 non-null   object
#  8   videos           1000 non-null   object
#  9   store            967 non-null    object
#  10  categories       1000 non-null   object
#  11  details          1000 non-null   object
#  12  parent_asin      1000 non-null   object
#  13  bought_together  0 non-null      object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 117.2+ KB

# %%
top_1000_beauty_df.head()
# Out:
#       main_category                                              title  \
# 50834    All Beauty        Elle 18 Eye Drama Kajal, Bold Black, 0.35 g
# 1403     All Beauty  Maybelline New York Colossal Bold Eyeliner, Bl...
# 51573    All Beauty  JIMIRE Fake Eyelashes Fluffy Volume 3D Faux Mi...
# 55874    All Beauty  THE ORDINARY Niacinamide 10% + Zinc 1% 30ml, 1...
# 32240    All Beauty  THE ORDINARY Niacinamide 10% + Zinc 1% 30ml, 1...
#
#        average_rating  rating_number  \
# 50834             4.2          30206
# 1403              4.3          27308
# 51573             4.4          16062
# 55874             4.5          15264
# 32240             4.5          15185
#
#                                                 features  \
# 50834                                                 []
# 1403                                                  []
# 51573                                                 []
# 55874  [This product has NO safety seal, Visibly regu...
# 32240  [This product has NO safety seal, Visibly regu...
#
#                                              description  price  \
# 50834      [Elle 18 Eye Drama Kajal, Bold Black, 0.35 g]    5.4
# 1403                                                  []    8.0
# 51573                                                 []    NaN
# 55874  [High-strength vitamin and mineral blemish for...    NaN
# 32240  [High-strength vitamin and mineral blemish for...    NaN
#
#                                                   images  \
# 50834  [{'thumb': 'https://m.media-amazon.com/images/...
# 1403   [{'thumb': 'https://m.media-amazon.com/images/...
# 51573  [{'thumb': 'https://m.media-amazon.com/images/...
# 55874  [{'thumb': 'https://m.media-amazon.com/images/...
# 32240  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                                   videos                store  \
# 50834  [{'title': 'Elle 18 Eye Drama Kajal - Review a...              Elle 18
# 1403   [{'title': 'Elle 18 Eye Drama Kajal - Review a...  Maybelline New York
# 51573                                                 []               JIMIRE
# 55874  [{'title': 'Customer Review for the Ordinary N...         THE ORDINARY
# 32240  [{'title': 'This transformed my skin! - Great ...         THE ORDINARY
#
#       categories                                            details  \
# 50834         []  {'Color': 'Black', 'Brand': 'Elle 18', 'Item F...
# 1403          []  {'Brand': 'Maybelline New York', 'Finish Type'...
# 51573         []  {'Brand': 'JIMIRE', 'Material': 'Faux Mink', '...
# 55874         []  {'Brand': 'THE ORDINARY', 'Primary Supplement ...
# 32240         []  {'Brand': 'THE ORDINARY', 'Primary Supplement ...
#
#       parent_asin bought_together
# 50834  B01LNT83KK            None
# 1403   B07S141T2R            None
# 51573  B08CVJJ518            None
# 55874  B01MDTVZTZ            None
# 32240  B06VSX2B1S            None

# %%
# save data
top_1000_beauty_df.to_csv('/content/drive/MyDrive/CS 229 Group Project/Data/top_1000_beauty_df.csv', index=False)

# %%
top_50_beauty_df.to_csv('/content/drive/MyDrive/CS 229 Group Project/Data/top_50_beauty_df.csv', index=False)

# %% [markdown]
# NLP Processing for consumer review data- Sentiment Score

# %%
P5Y_Overlapping_User_Fashion_df = pd.read_csv("/content/drive/MyDrive/CS 229 Group Project/Data/P5Y_Overlapping_User_Fashion_df.csv")

# %%
P5Y_Overlapping_User_Fashion_df.head()
# Out:
#    rating                     title  \
# 0     5.0                         A
# 1     2.0     Not what was expected
# 2     5.0                Nice shirt
# 3     3.0  Not for the large busted
# 4     5.0                    Cute T
#
#                                                 text  \
# 0                                              Great
# 1  There are lots of raw edges.  Not well made.  ...
# 2  I really liked this shirt when I received it. ...
# 3  If you are large chested, this isn’t for you. ...
# 4  I really like this Tshirt.  Quality fabric.  S...
#
#                                               images        asin parent_asin  \
# 0                                                 []  B07B4JXK8D  B07B4JXK8D
# 1                                                 []  B09DQ5M2BB  B09DQ5M2BB
# 2                                                 []  B095M3HHTJ  B095M3HHTJ
# 3                                                 []  B089PWHFVW  B089PWHFVW
# 4  [{'small_image_url': 'https://m.media-amazon.c...  B097DQPCP2  B097DQPCP2
#
#                         user_id      timestamp  helpful_vote  \
# 0  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ  1608426246701             0
# 1  AHREXOGQPZDA6354MHH4ETSF3MCQ  1634791843960             1
# 2  AHREXOGQPZDA6354MHH4ETSF3MCQ  1629080264160             1
# 3  AHREXOGQPZDA6354MHH4ETSF3MCQ  1628867386110             0
# 4  AHREXOGQPZDA6354MHH4ETSF3MCQ  1627391870221             3
#
#    verified_purchase    datetime
# 0               True  2020-12-20
# 1               True  2021-10-21
# 2               True  2021-08-16
# 3              False  2021-08-13
# 4               True  2021-07-27

# %%
from textblob import TextBlob

# Example of adding sentiment analysis to review data
def add_sentiment_scores(df):
    df['text'] = df['text'].astype(str)
    df['title'] = df['title'].astype(str)
    # TextBlob sentiment analysis
    df['sentiment_text'] = df['text'].apply(lambda text: TextBlob(text).sentiment.polarity)
    df['sentiment_title'] = df['title'].apply(lambda text: TextBlob(text).sentiment.polarity)
    return df

df_user = add_sentiment_scores(P5Y_Overlapping_User_Fashion_df)

# %%
df_user.head()
# Out:
#    rating                     title  \
# 0     5.0                         A
# 1     2.0     Not what was expected
# 2     5.0                Nice shirt
# 3     3.0  Not for the large busted
# 4     5.0                    Cute T
#
#                                                 text  \
# 0                                              Great
# 1  There are lots of raw edges.  Not well made.  ...
# 2  I really liked this shirt when I received it. ...
# 3  If you are large chested, this isn’t for you. ...
# 4  I really like this Tshirt.  Quality fabric.  S...
#
#                                               images        asin parent_asin  \
# 0                                                 []  B07B4JXK8D  B07B4JXK8D
# 1                                                 []  B09DQ5M2BB  B09DQ5M2BB
# 2                                                 []  B095M3HHTJ  B095M3HHTJ
# 3                                                 []  B089PWHFVW  B089PWHFVW
# 4  [{'small_image_url': 'https://m.media-amazon.c...  B097DQPCP2  B097DQPCP2
#
#                         user_id      timestamp  helpful_vote  \
# 0  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ  1608426246701             0
# 1  AHREXOGQPZDA6354MHH4ETSF3MCQ  1634791843960             1
# 2  AHREXOGQPZDA6354MHH4ETSF3MCQ  1629080264160             1
# 3  AHREXOGQPZDA6354MHH4ETSF3MCQ  1628867386110             0
# 4  AHREXOGQPZDA6354MHH4ETSF3MCQ  1627391870221             3
#
#    verified_purchase    datetime  sentiment_text  sentiment_title
# 0               True  2020-12-20        0.800000         0.000000
# 1               True  2021-10-21        0.086538        -0.100000
# 2               True  2021-08-16        0.471795         0.600000
# 3              False  2021-08-13        0.091429         0.214286
# 4               True  2021-07-27        0.264615         0.500000

# %%
# save data
df_user.to_csv('/content/drive/MyDrive/CS 229 Group Project/Data/df_user.csv', index=False)

# %% [markdown]
# Feature Engineering - avg rating per user

# %%
df_user = pd.read_csv("/content/drive/MyDrive/CS 229 Group Project/Data/df_user.csv")

# %%
df_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136241 entries, 0 to 136240
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   rating             136241 non-null  float64
#  1   title              136211 non-null  object
#  2   text               136203 non-null  object
#  3   images             136241 non-null  object
#  4   asin               136241 non-null  object
#  5   parent_asin        136241 non-null  object
#  6   user_id            136241 non-null  object
#  7   timestamp          136241 non-null  int64
#  8   helpful_vote       136241 non-null  int64
#  9   verified_purchase  136241 non-null  bool
#  10  datetime           136241 non-null  object
#  11  sentiment_text     136241 non-null  float64
#  12  sentiment_title    136241 non-null  float64
# dtypes: bool(1), float64(3), int64(2), object(7)
# memory usage: 12.6+ MB

# %%
average_ratings = df_user.groupby('user_id')['rating'].mean().reset_index()
average_ratings.rename(columns={'rating': 'user_average_rating'}, inplace=True)
df_user = pd.merge(df_user, average_ratings, on='user_id', how='left')

# %% [markdown]
# Feature Engineering - Standard Deviation of Ratings
#
# Measure the variability in a user's ratings. A high standard deviation indicates inconsistent opinions, which could be a useful feature.

# %%
std_ratings = df_user.groupby('user_id')['rating'].std().reset_index()

std_ratings.rename(columns={'rating': 'user_std_rating'}, inplace=True)
std_ratings['user_std_rating'].fillna(0, inplace=True)

df_user = pd.merge(df_user, std_ratings, on='user_id', how='left')
# Out:
# <ipython-input-46-027b0a364f83>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   std_ratings['user_std_rating'].fillna(0, inplace=True)

# %% [markdown]
# Feature Engineering - Avg sentiment scores per user

# %%
df_user["overall_sentiment"] = (df_user["sentiment_title"] + df_user["sentiment_text"])/2
average_sentiment = df_user.groupby('user_id')['overall_sentiment'].mean().reset_index()
average_sentiment.rename(columns={'overall_sentiment': 'avg_user_sentiment'}, inplace=True)

df_user = pd.merge(df_user, average_sentiment, on='user_id', how='left')

# %%
df_user.describe()
# Out:
#               rating     timestamp   helpful_vote  sentiment_text  \
# count  136241.000000  1.362410e+05  136241.000000   136241.000000
# mean        3.999016  1.584964e+12       0.525987        0.275845
# std         1.374421  4.284343e+10       2.868233        0.289758
# min         1.000000  1.514765e+12       0.000000       -1.000000
# 25%         3.000000  1.549918e+12       0.000000        0.081845
# 50%         5.000000  1.579032e+12       0.000000        0.258020
# 75%         5.000000  1.618204e+12       0.000000        0.466667
# max         5.000000  1.693158e+12     295.000000        1.000000
#
#        sentiment_title  user_average_rating  user_std_rating  \
# count    136241.000000        136241.000000    136241.000000
# mean          0.298108             3.999016         0.513531
# std           0.388670             1.164061         0.715311
# min          -1.000000             1.000000         0.000000
# 25%           0.000000             3.500000         0.000000
# 50%           0.295238             4.333333         0.000000
# 75%           0.600000             5.000000         0.957427
# max           1.000000             5.000000         2.828427
#
#        overall_sentiment  avg_user_sentiment
# count      136241.000000       136241.000000
# mean            0.286977            0.286977
# std             0.283033            0.237224
# min            -1.000000           -1.000000
# 25%             0.083333            0.146528
# 50%             0.295000            0.285218
# 75%             0.497917            0.431178
# max             1.000000            1.000000

# %% [markdown]
# Feature Engineering - Review Count
#
# Count the number of reviews posted by each user as a measure of engagement.

# %%
review_counts = df_user.groupby('user_id').size().reset_index(name='user_review_count')

df_user = pd.merge(df_user, review_counts, on='user_id', how='left')

# %%
df_user.describe()
# Out:
#               rating     timestamp   helpful_vote  sentiment_text  \
# count  136241.000000  1.362410e+05  136241.000000   136241.000000
# mean        3.999016  1.584964e+12       0.525987        0.275845
# std         1.374421  4.284343e+10       2.868233        0.289758
# min         1.000000  1.514765e+12       0.000000       -1.000000
# 25%         3.000000  1.549918e+12       0.000000        0.081845
# 50%         5.000000  1.579032e+12       0.000000        0.258020
# 75%         5.000000  1.618204e+12       0.000000        0.466667
# max         5.000000  1.693158e+12     295.000000        1.000000
#
#        sentiment_title  user_average_rating  user_std_rating  \
# count    136241.000000        136241.000000    136241.000000
# mean          0.298108             3.999016         0.513531
# std           0.388670             1.164061         0.715311
# min          -1.000000             1.000000         0.000000
# 25%           0.000000             3.500000         0.000000
# 50%           0.295238             4.333333         0.000000
# 75%           0.600000             5.000000         0.957427
# max           1.000000             5.000000         2.828427
#
#        overall_sentiment  avg_user_sentiment  user_review_count
# count      136241.000000       136241.000000      136241.000000
# mean            0.286977            0.286977           7.344360
# std             0.283033            0.237224          22.489425
# min            -1.000000           -1.000000           1.000000
# 25%             0.083333            0.146528           1.000000
# 50%             0.295000            0.285218           2.000000
# 75%             0.497917            0.431178           4.000000
# max             1.000000            1.000000         311.000000

# %% [markdown]
# Feature Engineering - avg review word count
# Average number of words per review, indicating how expressive or detailed the user is

# %%
df_user['word_count'] = df_user['text'].apply(lambda x: len(str(x).split()))

average_word_count = df_user.groupby('user_id')['word_count'].mean().reset_index()
average_word_count.rename(columns={'word_count': 'user_avg_word_count'}, inplace=True)

# Merge the average word counts with the original dataset (optional)
df_user = pd.merge(df_user, average_word_count, on='user_id', how='left')

# %% [markdown]
# Feature Engineering - Helpfulness Ratio
# Ratio of helpful votes to total reviews, to capture how valuable others find the user's reviews.

# %%
total_helpful_votes = df_user.groupby('user_id')['helpful_vote'].sum().reset_index()
total_reviews = df_user.groupby('user_id').size().reset_index(name='total_reviews')

helpfulness_data = pd.merge(total_helpful_votes, total_reviews, on='user_id')
helpfulness_data['helpfulness_ratio'] = helpfulness_data['helpful_vote'] / helpfulness_data['total_reviews']

df_user = pd.merge(df_user, helpfulness_data[['user_id', 'helpfulness_ratio']], on='user_id', how='left')

# %% [markdown]
# Feature Engineering: Verified Purchases Count
#
# Number of verified purchases, which might indicate a higher trust or authenticity in reviews.

# %%
verified_purchases = df_user[df_user['verified_purchase'] == True]

verified_counts = verified_purchases.groupby('user_id').size().reset_index(name='verified_purchase_count')

df_user = pd.merge(df_user, verified_counts, on='user_id', how='left')

# Fill NaN values with 0 where no verified purchases exist
df_user['verified_purchase_count'].fillna(0, inplace=True)
# Out:
# <ipython-input-170-6218f46dbe9e>:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_user['verified_purchase_count'].fillna(0, inplace=True)

# %%
df_user.describe()
# Out:
#               rating     timestamp   helpful_vote  sentiment_text  \
# count  136241.000000  1.362410e+05  136241.000000   136241.000000
# mean        3.999016  1.584964e+12       0.525987        0.275845
# std         1.374421  4.284343e+10       2.868233        0.289758
# min         1.000000  1.514765e+12       0.000000       -1.000000
# 25%         3.000000  1.549918e+12       0.000000        0.081845
# 50%         5.000000  1.579032e+12       0.000000        0.258020
# 75%         5.000000  1.618204e+12       0.000000        0.466667
# max         5.000000  1.693158e+12     295.000000        1.000000
#
#        sentiment_title  user_average_rating  user_std_rating  \
# count    136241.000000        136241.000000    136241.000000
# mean          0.298108             3.999016         0.513531
# std           0.388670             1.164061         0.715311
# min          -1.000000             1.000000         0.000000
# 25%           0.000000             3.500000         0.000000
# 50%           0.295238             4.333333         0.000000
# 75%           0.600000             5.000000         0.957427
# max           1.000000             5.000000         2.828427
#
#        overall_sentiment  avg_user_sentiment  user_review_count  \
# count      136241.000000       136241.000000      136241.000000
# mean            0.286977            0.286977           7.344360
# std             0.283033            0.237224          22.489425
# min            -1.000000           -1.000000           1.000000
# 25%             0.083333            0.146528           1.000000
# 50%             0.295000            0.285218           2.000000
# 75%             0.497917            0.431178           4.000000
# max             1.000000            1.000000         311.000000
#
#           word_count  user_avg_word_count  helpfulness_ratio  \
# count  136241.000000        136241.000000      136241.000000
# mean       37.513678            37.513678           0.525987
# std        47.898293            41.795957           2.135346
# min         0.000000             0.000000           0.000000
# 25%         9.000000            10.500000           0.000000
# 50%        22.000000            24.000000           0.000000
# 75%        48.000000            50.000000           0.456522
# max      1757.000000           952.000000         152.000000
#
#        verified_purchase_count
# count            136241.000000
# mean                  2.005982
# std                   2.900913
# min                   0.000000
# 25%                   1.000000
# 50%                   1.000000
# 75%                   2.000000
# max                  50.000000

# %% [markdown]
# # Drop userless features and save user data

# %%
df_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136241 entries, 0 to 136240
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   rating                   136241 non-null  float64
#  1   title                    136211 non-null  object
#  2   text                     136203 non-null  object
#  3   images                   136241 non-null  object
#  4   asin                     136241 non-null  object
#  5   parent_asin              136241 non-null  object
#  6   user_id                  136241 non-null  object
#  7   timestamp                136241 non-null  int64
#  8   helpful_vote             136241 non-null  int64
#  9   verified_purchase        136241 non-null  bool
#  10  datetime                 136241 non-null  object
#  11  sentiment_text           136241 non-null  float64
#  12  sentiment_title          136241 non-null  float64
#  13  user_average_rating      136241 non-null  float64
#  14  user_std_rating          136241 non-null  float64
#  15  overall_sentiment        136241 non-null  float64
#  16  avg_user_sentiment       136241 non-null  float64
#  17  user_review_count        136241 non-null  int64
#  18  word_count               136241 non-null  int64
#  19  user_avg_word_count      136241 non-null  float64
#  20  helpfulness_ratio        136241 non-null  float64
#  21  verified_purchase_count  136241 non-null  float64
# dtypes: bool(1), float64(10), int64(4), object(7)
# memory usage: 22.0+ MB

# %%
df_user.drop(columns=['title', 'text','images','asin','timestamp','helpful_vote', 'verified_purchase', 'sentiment_text', 'sentiment_title', 'overall_sentiment'], inplace=True)

# %%
df_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136241 entries, 0 to 136240
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   rating                   136241 non-null  float64
#  1   parent_asin              136241 non-null  object
#  2   user_id                  136241 non-null  object
#  3   datetime                 136241 non-null  object
#  4   user_average_rating      136241 non-null  float64
#  5   user_std_rating          136241 non-null  float64
#  6   avg_user_sentiment       136241 non-null  float64
#  7   user_review_count        136241 non-null  int64
#  8   word_count               136241 non-null  int64
#  9   user_avg_word_count      136241 non-null  float64
#  10  helpfulness_ratio        136241 non-null  float64
#  11  verified_purchase_count  136241 non-null  float64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 12.5+ MB

# %%
# check replicated uer
df_user['user_id'].value_counts()
# Out:
# user_id
# AGZZXSMMS4WRHHJRBUJZI4FZDHKQ    311
# AG73BVBKUOH22USSFJA5ZWL7AKXA    205
# AEYVPPWR4CIKWX4BGYKCBCDL2CZQ    175
# AFQQQ5LGNSQUEBGDCYBAZZE5T3DA    145
# AG3HKK7MIKRQ7DOTNDOE63X2WJGQ    145
#                                ...
# AGNHLNTB2WEPQBB5B75EJOCPIF7Q      1
# AH3WBPSGKH6NEIJJFFBCQ3AC74JQ      1
# AEJ6DB7N3XUMRMXMIA4QBKPFY2HQ      1
# AFE6YWI63SQJ7FUPJ5Q3EP6I3GQA      1
# AGIPFBZXI7LTISXRWUH36PM3XTIA      1
# Name: count, Length: 80981, dtype: int64

# %% [markdown]
# Feature engineering  - difference betweeen user rating and product avg rating

# %%
Meta_Fashion_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 826108 entries, 0 to 826107
# Data columns (total 14 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   main_category    826108 non-null  object
#  1   title            826108 non-null  object
#  2   average_rating   826108 non-null  float64
#  3   rating_number    826108 non-null  int64
#  4   features         826108 non-null  object
#  5   description      826108 non-null  object
#  6   price            50249 non-null   float64
#  7   images           826108 non-null  object
#  8   videos           826108 non-null  object
#  9   store            799270 non-null  object
#  10  categories       826108 non-null  object
#  11  details          826108 non-null  object
#  12  parent_asin      826108 non-null  object
#  13  bought_together  0 non-null       object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 88.2+ MB

# %%
# check difference betweeen user rating from df_user and product avg rating from meta data
merged_df = df_user.merge(Meta_Fashion_df[['parent_asin', 'average_rating']], on='parent_asin', how='left')

# %%
merged_df['rating_diff'] = merged_df['rating'] - merged_df['average_rating']
avg_diff_per_user = merged_df.groupby('user_id')['rating_diff'].mean().reset_index()
avg_diff_per_user.rename(columns={'rating_diff': 'user_avgrating_diff'}, inplace=True)
df_user = pd.merge(df_user, avg_diff_per_user, on='user_id', how='left')

# %%
df_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136241 entries, 0 to 136240
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   rating                   136241 non-null  float64
#  1   parent_asin              136241 non-null  object
#  2   user_id                  136241 non-null  object
#  3   datetime                 136241 non-null  object
#  4   user_average_rating      136241 non-null  float64
#  5   user_std_rating          136241 non-null  float64
#  6   avg_user_sentiment       136241 non-null  float64
#  7   user_review_count        136241 non-null  int64
#  8   word_count               136241 non-null  int64
#  9   user_avg_word_count      136241 non-null  float64
#  10  helpfulness_ratio        136241 non-null  float64
#  11  verified_purchase_count  136241 non-null  float64
#  12  user_avgrating_diff      136241 non-null  float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 13.5+ MB

# %%
df_user.drop(columns=['rating', 'parent_asin', 'datetime'], inplace=True)

# %%
# only keep unique user info
unique_user_df = df_user.drop_duplicates(subset='user_id')

# %%
unique_user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80981 entries, 0 to 136240
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  80981 non-null  object
#  1   user_average_rating      80981 non-null  float64
#  2   user_std_rating          80981 non-null  float64
#  3   avg_user_sentiment       80981 non-null  float64
#  4   user_review_count        80981 non-null  int64
#  5   word_count               80981 non-null  int64
#  6   user_avg_word_count      80981 non-null  float64
#  7   helpfulness_ratio        80981 non-null  float64
#  8   verified_purchase_count  80981 non-null  float64
#  9   user_avgrating_diff      80981 non-null  float64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 6.8+ MB

# %%
# save data
unique_user_df.to_csv('/content/drive/MyDrive/CS 229 Group Project/Data/unique_user_df.csv', index=False)

# %% [markdown]
# # Combine user data with product info

# %%
# import data
unique_user_df = pd.read_csv("/content/drive/MyDrive/CS 229 Group Project/Data/unique_user_df.csv")

# %%
top_1000_beauty_df = pd.read_csv('/content/drive/MyDrive/CS 229 Group Project/Data/top_1000_beauty_df.csv')

# %%
unique_user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80981 entries, 0 to 80980
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  80981 non-null  object
#  1   user_average_rating      80981 non-null  float64
#  2   user_std_rating          80981 non-null  float64
#  3   avg_user_sentiment       80981 non-null  float64
#  4   user_review_count        80981 non-null  int64
#  5   word_count               80981 non-null  int64
#  6   user_avg_word_count      80981 non-null  float64
#  7   helpfulness_ratio        80981 non-null  float64
#  8   verified_purchase_count  80981 non-null  float64
#  9   user_avgrating_diff      80981 non-null  float64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 6.2+ MB

# %%
top_1000_beauty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   main_category    1000 non-null   object
#  1   title            999 non-null    object
#  2   average_rating   1000 non-null   float64
#  3   rating_number    1000 non-null   int64
#  4   features         1000 non-null   object
#  5   description      1000 non-null   object
#  6   price            486 non-null    float64
#  7   images           1000 non-null   object
#  8   videos           1000 non-null   object
#  9   store            967 non-null    object
#  10  categories       1000 non-null   object
#  11  details          1000 non-null   object
#  12  parent_asin      1000 non-null   object
#  13  bought_together  0 non-null      float64
# dtypes: float64(3), int64(1), object(10)
# memory usage: 109.5+ KB

# %%
print(top_1000_beauty_df[['average_rating', 'parent_asin']].describe(include='all'))
print(top_1000_beauty_df[['average_rating', 'parent_asin']].isnull().sum())
# Out:
#         average_rating parent_asin
# count       1000.00000        1000
# unique             NaN        1000
# top                NaN  B01LNT83KK
# freq               NaN           1
# mean           4.33030         NaN
# std            0.36901         NaN
# min            1.40000         NaN
# 25%            4.20000         NaN
# 50%            4.40000         NaN
# 75%            4.60000         NaN
# max            4.90000         NaN
# average_rating    0
# parent_asin       0
# dtype: int64

# %%
prod_ratings = top_1000_beauty_df.pivot_table(
    values='average_rating',
    columns='parent_asin',
    aggfunc='mean'
)

prod_ratings_df = pd.DataFrame(prod_ratings)

prod_ratings_df = prod_ratings_df.transpose()
prod_ratings_df.reset_index(inplace=True)
prod_ratings_df.columns = ['parent_asin', 'average_rating']

print(prod_ratings_df.info())
print(prod_ratings_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   parent_asin     1000 non-null   object
#  1   average_rating  1000 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 15.8+ KB
# None
#   parent_asin  average_rating
# 0  1891129716             4.7
# 1  4293845755             4.4
# 2  B00011JN5G             3.0
# 3  B0002LBKGU             4.4
# 4  B0002SGSNI             4.6

# %%
prod_ratings_df = prod_ratings_df.set_index('parent_asin').T
prod_ratings_df.columns = ['avg_rating_' + col for col in prod_ratings_df.columns]

prod_ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, average_rating to average_rating
# Columns: 1000 entries, avg_rating_1891129716 to avg_rating_B0CDNZ7F2V
# dtypes: float64(1000)
# memory usage: 7.8+ KB

# %%
input_df = unique_user_df.join(prod_ratings_df, how='cross')

# %%
input_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80981 entries, 0 to 80980
# Columns: 1010 entries, user_id to avg_rating_B0CDNZ7F2V
# dtypes: float64(1007), int64(2), object(1)
# memory usage: 624.0+ MB

# %%
# save input_data
input_df.to_csv('/content/drive/MyDrive/CS 229 Group Project/Data/input_df.csv', index=False)

# %% [markdown]
# Prepare y labels

# %%
input_df = pd.read_csv("/content/drive/MyDrive/CS 229 Group Project/Data/input_df.csv")

# %%
input_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80981 entries, 0 to 80980
# Columns: 1010 entries, user_id to avg_rating_B0CDNZ7F2V
# dtypes: float64(1007), int64(2), object(1)
# memory usage: 624.0+ MB

# %%
top_1000_beauty_df = pd.read_csv('/content/drive/MyDrive/CS 229 Group Project/Data/top_1000_beauty_df.csv')

# %%
# extract unique user_id
unique_user_ids = input_df['user_id'].unique()

# %%
# for beauty user review data, filter the reviews to include only the top 1000 products
top_1000_asin = top_1000_beauty_df['parent_asin'].unique()

# %%
filtered_beauty = Beauty_User_df[Beauty_User_df['parent_asin'].isin(top_1000_asin)]

input_df.set_index('user_id', inplace=True)
filtered_beauty.set_index('user_id', inplace=True)

# %%
pivot_purchase = filtered_beauty.pivot_table(index='user_id', columns='parent_asin', values='verified_purchase', fill_value=False)
pivot_rating = filtered_beauty.pivot_table(index='user_id', columns='parent_asin', values='rating')
# Out:
# parent_asin                  1891129716 4293845755 B00011JN5G B0002LBKGU  \
# user_id
# AE223EVQI22TZJEZG3F2PG5Y57FQ      False      False      False      False
# AE22BJCLGXGMOFCGOUPWWIZH2Y6Q      False      False      False      False
# AE22CNEQCUSRHXTD5SBMSR3DDEIQ      False      False      False      False
# AE22DJ3KMLPQS5JXQULPZTUDBLWQ      False      False      False      False
# AE22EBF2Z3HHH2NIDGWE74GDGY7A      False      False      False      False
# ...                                 ...        ...        ...        ...
# AHZZWPY2VSFZRFHI7OC4JNCAVLJQ      False      False      False      False
# AHZZXK4KCAJTTIZZB76ZNJKDKRMQ      False      False      False      False
# AHZZXZDR6DC6XTALQK4JBA2GRZOQ      False      False      False      False
# AHZZZJP24QUSB5XWW6MAXYBZZZSQ      False      False      False      False
# AHZZZSOTVOVACVK2WWXL4ITEAPIA      False      False      False      False
#
# parent_asin                  B0002SGSNI B00068DISW B0006NY3WW B000ARUO8G  \
# user_id
# AE223EVQI22TZJEZG3F2PG5Y57FQ      False      False      False      False
# AE22BJCLGXGMOFCGOUPWWIZH2Y6Q      False      False      False      False
# AE22CNEQCUSRHXTD5SBMSR3DDEIQ      False      False      False      False
# AE22DJ3KMLPQS5JXQULPZTUDBLWQ      False      False      False      False
# AE22EBF2Z3HHH2NIDGWE74GDGY7A      False      False      False      False
# ...                                 ...        ...        ...        ...
# AHZZWPY2VSFZRFHI7OC4JNCAVLJQ      False      False      False      False
# AHZZXK4KCAJTTIZZB76ZNJKDKRMQ      False      False      False      False
# AHZZXZDR6DC6XTALQK4JBA2GRZOQ      False      False      False      False
# AHZZZJP24QUSB5XWW6MAXYBZZZSQ      False      False      False      False
# AHZZZSOTVOVACVK2WWXL4ITEAPIA      False      False      False      False
#
# parent_asin                  B000BOZ8UM B000EVGPE0  ... B0C3LVTX2V B0C52PWCV2  \
# user_id                                             ...
# AE223EVQI22TZJEZG3F2PG5Y57FQ      False      False  ...      False      False
# AE22BJCLGXGMOFCGOUPWWIZH2Y6Q      False      False  ...      False      False
# AE22CNEQCUSRHXTD5SBMSR3DDEIQ      False      False  ...      False      False
# AE22DJ3KMLPQS5JXQULPZTUDBLWQ      False      False  ...      False      False
# AE22EBF2Z3HHH2NIDGWE74GDGY7A      False      False  ...      False      False
# ...                                 ...        ...  ...        ...        ...
# AHZZWPY2VSFZRFHI7OC4JNCAVLJQ      False      False  ...      False      False
# AHZZXK4KCAJTTIZZB76ZNJKDKRMQ      False      False  ...      False      False
# AHZZXZDR6DC6XTALQK4JBA2GRZOQ      False      False  ...      False      False
# AHZZZJP24QUSB5XWW6MAXYBZZZSQ      False      False  ...      False      False
# AHZZZSOTVOVACVK2WWXL4ITEAPIA      False      False  ...      False      False
#
# parent_asin                  B0C58XKGCS B0C5FZDPD3 B0C6R11392 B0C9CWKY9G  \
# user_id
# AE223EVQI22TZJEZG3F2PG5Y57FQ      False      False      False      False
# AE22BJCLGXGMOFCGOUPWWIZH2Y6Q      False      False      False      False
# AE22CNEQCUSRHXTD5SBMSR3DDEIQ      False      False      False      False
# AE22DJ3KMLPQS5JXQULPZTUDBLWQ      False      False      False      False
# AE22EBF2Z3HHH2NIDGWE74GDGY7A      False      False      False      False
# ...                                 ...        ...        ...        ...
# AHZZWPY2VSFZRFHI7OC4JNCAVLJQ      False      False      False      False
# AHZZXK4KCAJTTIZZB76ZNJKDKRMQ      False      False      False      False
# AHZZXZDR6DC6XTALQK4JBA2GRZOQ      False      False      False      False
# AHZZZJP24QUSB5XWW6MAXYBZZZSQ      False      False      False      False
# AHZZZSOTVOVACVK2WWXL4ITEAPIA      False      False      False      False
#
# parent_asin                  B0CBBZ9MJ4 B0CC929DZZ B0CC9YWMGV B0CDNZ7F2V
# user_id
# AE223EVQI22TZJEZG3F2PG5Y57FQ      False      False      False      False
# AE22BJCLGXGMOFCGOUPWWIZH2Y6Q      False      False      False      False
# AE22CNEQCUSRHXTD5SBMSR3DDEIQ      False      False      False      False
# AE22DJ3KMLPQS5JXQULPZTUDBLWQ      False      False      False      False
# AE22EBF2Z3HHH2NIDGWE74GDGY7A      False      False      False      False
# ...                                 ...        ...        ...        ...
# AHZZWPY2VSFZRFHI7OC4JNCAVLJQ      False      False      False      False
# AHZZXK4KCAJTTIZZB76ZNJKDKRMQ      False      False      False      False
# AHZZXZDR6DC6XTALQK4JBA2GRZOQ      False      False      False      False
# AHZZZJP24QUSB5XWW6MAXYBZZZSQ      False      False      False      False
# AHZZZSOTVOVACVK2WWXL4ITEAPIA      False      False      False      False
#
# [111342 rows x 1000 columns]

# %%
pivot_purchase.describe()
# Out:
# parent_asin 1891129716 4293845755 B00011JN5G B0002LBKGU B0002SGSNI B00068DISW  \
# count           111342     111342     111342     111342     111342     111342
# unique               2          2          2          2          2          2
# top              False      False      False      False      False      False
# freq            111340     111335     111150     111341     111196     111330
#
# parent_asin B0006NY3WW B000ARUO8G B000BOZ8UM B000EVGPE0  ... B0C3LVTX2V  \
# count           111342     111342     111342     111342  ...     111342
# unique               2          2          2          2  ...          2
# top              False      False      False      False  ...      False
# freq            111319     111341     111155     111341  ...     111184
#
# parent_asin B0C52PWCV2 B0C58XKGCS B0C5FZDPD3 B0C6R11392 B0C9CWKY9G B0CBBZ9MJ4  \
# count           111342     111342     111342     111342     111342     111342
# unique               2          2          2          2          2          2
# top              False      False      False      False      False      False
# freq            111230     111261     111275     111245     110214     111339
#
# parent_asin B0CC929DZZ B0CC9YWMGV B0CDNZ7F2V
# count           111342     111342     111342
# unique               2          2          2
# top              False      False      False
# freq            111326     111338     111081
#
# [4 rows x 1000 columns]

# %%
# Join pivoted data back to input_df
input_df = input_df.join(pivot_purchase.add_prefix('y_verified_purchase_'), on='user_id')
input_df = input_df.join(pivot_rating.add_prefix('y_rating_'), on='user_id')

# %%
input_df.head()
# Out:
#                               user_average_rating  user_std_rating  \
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ             5.000000         0.000000
# AHREXOGQPZDA6354MHH4ETSF3MCQ             4.000000         1.414214
# AFSKPY37N3C43SOI5IEXEK5JSIYA             4.571429         0.786796
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA             4.000000         1.414214
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA             4.000000         0.000000
#
#                               avg_user_sentiment  user_review_count  \
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ            0.400000                  1
# AHREXOGQPZDA6354MHH4ETSF3MCQ            0.265162                  5
# AFSKPY37N3C43SOI5IEXEK5JSIYA            0.305471                  7
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA            0.335173                  2
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA            0.200000                  1
#
#                               word_count  user_avg_word_count  \
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ           1             1.000000
# AHREXOGQPZDA6354MHH4ETSF3MCQ          29            68.800000
# AFSKPY37N3C43SOI5IEXEK5JSIYA          83            87.285714
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA          33            17.000000
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA           9             9.000000
#
#                               helpfulness_ratio  verified_purchase_count  \
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ                0.0                      1.0
# AHREXOGQPZDA6354MHH4ETSF3MCQ                1.0                      4.0
# AFSKPY37N3C43SOI5IEXEK5JSIYA                0.0                      0.0
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA                0.0                      2.0
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA                0.0                      1.0
#
#                               user_avgrating_diff  avg_rating_1891129716  ...  \
# user_id                                                                   ...
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ             0.700000                    4.7  ...
# AHREXOGQPZDA6354MHH4ETSF3MCQ             0.340000                    4.7  ...
# AFSKPY37N3C43SOI5IEXEK5JSIYA             0.614286                    4.7  ...
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA             0.000000                    4.7  ...
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA             0.900000                    4.7  ...
#
#                               y_rating_B0C3LVTX2V  y_rating_B0C52PWCV2  \
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ                  NaN                  NaN
# AHREXOGQPZDA6354MHH4ETSF3MCQ                  NaN                  NaN
# AFSKPY37N3C43SOI5IEXEK5JSIYA                  NaN                  NaN
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA                  NaN                  NaN
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA                  NaN                  NaN
#
#                               y_rating_B0C58XKGCS  y_rating_B0C5FZDPD3  \
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ                  NaN                  NaN
# AHREXOGQPZDA6354MHH4ETSF3MCQ                  NaN                  NaN
# AFSKPY37N3C43SOI5IEXEK5JSIYA                  NaN                  NaN
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA                  NaN                  NaN
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA                  NaN                  NaN
#
#                               y_rating_B0C6R11392  y_rating_B0C9CWKY9G  \
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ                  NaN                  NaN
# AHREXOGQPZDA6354MHH4ETSF3MCQ                  NaN                  NaN
# AFSKPY37N3C43SOI5IEXEK5JSIYA                  NaN                  NaN
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA                  NaN                  NaN
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA                  NaN                  NaN
#
#                               y_rating_B0CBBZ9MJ4  y_rating_B0CC929DZZ  \
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ                  NaN                  NaN
# AHREXOGQPZDA6354MHH4ETSF3MCQ                  NaN                  NaN
# AFSKPY37N3C43SOI5IEXEK5JSIYA                  NaN                  NaN
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA                  NaN                  NaN
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA                  NaN                  NaN
#
#                               y_rating_B0CC9YWMGV  y_rating_B0CDNZ7F2V
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ                  NaN                  NaN
# AHREXOGQPZDA6354MHH4ETSF3MCQ                  NaN                  NaN
# AFSKPY37N3C43SOI5IEXEK5JSIYA                  NaN                  NaN
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA                  NaN                  NaN
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA                  NaN                  NaN
#
# [5 rows x 3009 columns]

# %%
for asin in top_1000_asin:
       # Find the row in Meta_Beauty_df where parent_asin matches asin
       row = Meta_Beauty_df.loc[Meta_Beauty_df['parent_asin'] == asin]
       if not row.empty:
           average_rating = row['average_rating'].iloc[0]
           if f'y_rating_{asin}' in input_df.columns:
               input_df[f'y_rating_{asin}'].fillna(average_rating, inplace=True)
           else:
               input_df[f'y_rating_{asin}'] = average_rating
       else:
           print(f"ASIN {asin} not found in Meta_Beauty_df")
# Out:
# <ipython-input-31-8474e510a226>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   input_df[f'y_rating_{asin}'].fillna(average_rating, inplace=True)

# %%
# check data
rating_columns = [col for col in input_df.columns if col.startswith('y_rating_')]

print(input_df[rating_columns].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80981 entries, AFQLNQNQYFWQZPJQZS6V3NZU4QBQ to AGIPFBZXI7LTISXRWUH36PM3XTIA
# Columns: 1000 entries, y_rating_1891129716 to y_rating_B0CDNZ7F2V
# dtypes: float64(1000)
# memory usage: 618.5+ MB
# None

# %%
# Filter the columns that start with 'y_verified_purchase'
rating_columns = [col for col in input_df.columns if col.startswith('y_verified_purchase')]

input_df[rating_columns] = input_df[rating_columns].fillna(False)

# Verify the changes by checking again for NaN values
na_check_updated = input_df[rating_columns].isna().any()
print(na_check_updated)
# Out:
# <ipython-input-41-013ebc13a792>:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   input_df[rating_columns] = input_df[rating_columns].fillna(False)
# y_verified_purchase_1891129716    False
# y_verified_purchase_4293845755    False
# y_verified_purchase_B00011JN5G    False
# y_verified_purchase_B0002LBKGU    False
# y_verified_purchase_B0002SGSNI    False
#                                   ...
# y_verified_purchase_B0C9CWKY9G    False
# y_verified_purchase_B0CBBZ9MJ4    False
# y_verified_purchase_B0CC929DZZ    False
# y_verified_purchase_B0CC9YWMGV    False
# y_verified_purchase_B0CDNZ7F2V    False
# Length: 1000, dtype: bool

# %%
rating_columns = [col for col in input_df.columns if col.startswith('y_verified_purchase')]
verified_purchase_counts = {}
for column in rating_columns:
    verified_purchase_counts[column] = input_df[column].value_counts()

verified_purchase_counts_df = pd.DataFrame(verified_purchase_counts)

# Print the result
print(verified_purchase_counts_df)
# Out:
#        y_verified_purchase_1891129716  y_verified_purchase_4293845755  \
# False                         80981.0                           80979
# 1.0                               NaN                               2
#
#        y_verified_purchase_B00011JN5G  y_verified_purchase_B0002LBKGU  \
# False                           80957                         80981.0
# 1.0                                24                             NaN
#
#        y_verified_purchase_B0002SGSNI  y_verified_purchase_B00068DISW  \
# False                           80953                           80977
# 1.0                                28                               4
#
#        y_verified_purchase_B0006NY3WW  y_verified_purchase_B000ARUO8G  \
# False                         80981.0                         80981.0
# 1.0                               NaN                             NaN
#
#        y_verified_purchase_B000BOZ8UM  y_verified_purchase_B000EVGPE0  ...  \
# False                           80964                         80981.0  ...
# 1.0                                17                             NaN  ...
#
#        y_verified_purchase_B0C3LVTX2V  y_verified_purchase_B0C52PWCV2  \
# False                           80950                           80961
# 1.0                                31                              20
#
#        y_verified_purchase_B0C58XKGCS  y_verified_purchase_B0C5FZDPD3  \
# False                           80972                           80975
# 1.0                                 9                               6
#
#        y_verified_purchase_B0C6R11392  y_verified_purchase_B0C9CWKY9G  \
# False                           80969                           80831
# 1.0                                12                             150
#
#        y_verified_purchase_B0CBBZ9MJ4  y_verified_purchase_B0CC929DZZ  \
# False                         80981.0                           80978
# 1.0                               NaN                               3
#
#        y_verified_purchase_B0CC9YWMGV  y_verified_purchase_B0CDNZ7F2V
# False                         80981.0                           80930
# 1.0                               NaN                              51
#
# [2 rows x 1000 columns]

# %%
input_df.head()
# Out:
#                               user_average_rating  user_std_rating  \
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ             5.000000         0.000000
# AHREXOGQPZDA6354MHH4ETSF3MCQ             4.000000         1.414214
# AFSKPY37N3C43SOI5IEXEK5JSIYA             4.571429         0.786796
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA             4.000000         1.414214
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA             4.000000         0.000000
#
#                               avg_user_sentiment  user_review_count  \
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ            0.400000                  1
# AHREXOGQPZDA6354MHH4ETSF3MCQ            0.265162                  5
# AFSKPY37N3C43SOI5IEXEK5JSIYA            0.305471                  7
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA            0.335173                  2
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA            0.200000                  1
#
#                               word_count  user_avg_word_count  \
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ           1             1.000000
# AHREXOGQPZDA6354MHH4ETSF3MCQ          29            68.800000
# AFSKPY37N3C43SOI5IEXEK5JSIYA          83            87.285714
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA          33            17.000000
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA           9             9.000000
#
#                               helpfulness_ratio  verified_purchase_count  \
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ                0.0                      1.0
# AHREXOGQPZDA6354MHH4ETSF3MCQ                1.0                      4.0
# AFSKPY37N3C43SOI5IEXEK5JSIYA                0.0                      0.0
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA                0.0                      2.0
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA                0.0                      1.0
#
#                               user_avgrating_diff  avg_rating_1891129716  ...  \
# user_id                                                                   ...
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ             0.700000                    4.7  ...
# AHREXOGQPZDA6354MHH4ETSF3MCQ             0.340000                    4.7  ...
# AFSKPY37N3C43SOI5IEXEK5JSIYA             0.614286                    4.7  ...
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA             0.000000                    4.7  ...
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA             0.900000                    4.7  ...
#
#                               y_rating_B0C3LVTX2V  y_rating_B0C52PWCV2  \
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ                  4.3                  4.7
# AHREXOGQPZDA6354MHH4ETSF3MCQ                  4.3                  4.7
# AFSKPY37N3C43SOI5IEXEK5JSIYA                  4.3                  4.7
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA                  4.3                  4.7
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA                  4.3                  4.7
#
#                               y_rating_B0C58XKGCS  y_rating_B0C5FZDPD3  \
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ                  3.9                  4.6
# AHREXOGQPZDA6354MHH4ETSF3MCQ                  3.9                  4.6
# AFSKPY37N3C43SOI5IEXEK5JSIYA                  3.9                  4.6
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA                  3.9                  4.6
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA                  3.9                  4.6
#
#                               y_rating_B0C6R11392  y_rating_B0C9CWKY9G  \
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ                  4.2                  4.8
# AHREXOGQPZDA6354MHH4ETSF3MCQ                  4.2                  4.8
# AFSKPY37N3C43SOI5IEXEK5JSIYA                  4.2                  4.8
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA                  4.2                  4.8
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA                  4.2                  4.8
#
#                               y_rating_B0CBBZ9MJ4  y_rating_B0CC929DZZ  \
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ                  1.4                  4.6
# AHREXOGQPZDA6354MHH4ETSF3MCQ                  1.4                  4.6
# AFSKPY37N3C43SOI5IEXEK5JSIYA                  1.4                  4.6
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA                  1.4                  4.6
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA                  1.4                  4.6
#
#                               y_rating_B0CC9YWMGV  y_rating_B0CDNZ7F2V
# user_id
# AFQLNQNQYFWQZPJQZS6V3NZU4QBQ                  4.5                  4.6
# AHREXOGQPZDA6354MHH4ETSF3MCQ                  4.5                  4.6
# AFSKPY37N3C43SOI5IEXEK5JSIYA                  4.5                  4.6
# AFGEM6BXCYHUILEOA3P2ZYBEF2TA                  4.5                  4.6
# AHZ6XMOLEWA67S3TX7IWEXXGWSOA                  4.5                  4.6
#
# [5 rows x 3009 columns]

# %%
# save data
input_df.to_csv('/content/drive/MyDrive/CS 229 Group Project/Data/input_labels_df.csv', index=False)

# %% [markdown]
# ## Split Data

# %%
input_df = pd.read_csv("/content/drive/MyDrive/CS 229 Group Project/Data/input_labels_df.csv")
# Out:
# <ipython-input-3-a196022f355a>:1: DtypeWarning: Columns (1010,1011,1013,1014,1017,1019,1020,1022,1023,1026,1028,1029,1032,1033,1034,1039,1040,1041,1042,1043,1044,1045,1046,1047,1048,1049,1050,1051,1052,1053,1055,1056,1057,1058,1060,1063,1064,1067,1069,1070,1071,1072,1074,1075,1076,1077,1079,1080,1081,1082,1085,1088,1089,1091,1092,1093,1094,1096,1097,1099,1101,1102,1103,1104,1105,1106,1108,1110,1111,1113,1115,1116,1117,1118,1121,1122,1123,1124,1125,1127,1128,1129,1131,1132,1136,1139,1140,1141,1142,1143,1145,1146,1147,1148,1150,1151,1152,1154,1159,1160,1163,1164,1166,1167,1168,1169,1170,1171,1172,1173,1174,1175,1178,1179,1180,1182,1183,1184,1185,1186,1188,1189,1190,1192,1193,1197,1199,1200,1201,1202,1203,1205,1206,1207,1208,1210,1211,1212,1216,1217,1218,1219,1220,1224,1227,1228,1230,1231,1232,1234,1235,1236,1237,1238,1239,1240,1241,1242,1243,1244,1245,1247,1248,1249,1252,1253,1256,1259,1260,1261,1263,1264,1266,1267,1268,1269,1271,1272,1273,1274,1275,1276,1277,1278,1280,1281,1283,1284,1285,1286,1287,1288,1290,1291,1292,1293,1294,1295,1296,1297,1298,1299,1300,1301,1303,1304,1305,1306,1307,1308,1309,1310,1311,1312,1313,1314,1315,1316,1317,1318,1319,1320,1323,1324,1325,1327,1328,1329,1330,1331,1332,1333,1334,1335,1336,1337,1338,1339,1340,1341,1342,1343,1344,1345,1346,1347,1348,1349,1350,1351,1352,1353,1354,1356,1357,1358,1359,1360,1363,1364,1365,1368,1369,1370,1371,1372,1373,1374,1375,1376,1377,1379,1380,1382,1387,1388,1389,1390,1391,1392,1394,1397,1401,1403,1406,1407,1410,1411,1414,1416,1417,1418,1419,1420,1422,1423,1424,1427,1428,1429,1430,1431,1432,1433,1434,1435,1436,1437,1438,1439,1440,1441,1443,1444,1446,1448,1449,1450,1451,1452,1453,1454,1455,1457,1458,1459,1460,1461,1462,1463,1464,1465,1467,1468,1469,1470,1471,1473,1474,1475,1476,1477,1478,1482,1483,1485,1486,1487,1488,1489,1491,1493,1494,1495,1496,1499,1500,1501,1503,1504,1506,1507,1508,1510,1511,1512,1514,1517,1518,1519,1520,1521,1523,1524,1525,1526,1527,1528,1529,1533,1534,1535,1536,1537,1539,1541,1542,1543,1544,1546,1547,1548,1549,1550,1552,1553,1555,1556,1557,1559,1560,1561,1562,1563,1564,1565,1566,1567,1568,1569,1570,1571,1572,1574,1575,1576,1577,1578,1579,1580,1581,1583,1584,1585,1586,1587,1588,1589,1590,1591,1593,1594,1595,1598,1599,1600,1601,1602,1603,1604,1605,1606,1607,1609,1610,1611,1612,1613,1614,1615,1616,1617,1618,1619,1620,1621,1622,1623,1624,1625,1626,1627,1628,1629,1630,1631,1632,1633,1634,1635,1636,1637,1638,1639,1640,1641,1642,1643,1644,1645,1646,1647,1648,1649,1650,1651,1652,1653,1654,1655,1656,1657,1658,1659,1661,1662,1663,1664,1666,1667,1668,1671,1673,1674,1675,1676,1678,1679,1680,1682,1683,1684,1685,1688,1689,1690,1691,1692,1693,1694,1695,1696,1697,1698,1699,1700,1701,1702,1704,1705,1706,1707,1709,1712,1713,1714,1716,1717,1718,1719,1720,1721,1722,1723,1725,1726,1727,1728,1729,1730,1731,1732,1733,1734,1735,1736,1737,1739,1740,1741,1742,1743,1744,1745,1746,1747,1748,1749,1751,1752,1753,1754,1755,1756,1757,1758,1759,1760,1761,1762,1763,1764,1765,1766,1767,1768,1769,1770,1771,1772,1773,1774,1775,1776,1777,1778,1779,1780,1781,1782,1783,1784,1786,1787,1788,1791,1792,1793,1794,1795,1796,1797,1798,1800,1803,1804,1805,1806,1807,1808,1809,1811,1815,1817,1818,1821,1822,1823,1824,1825,1826,1827,1828,1829,1832,1833,1834,1835,1836,1838,1840,1841,1842,1843,1845,1846,1847,1850,1852,1853,1854,1856,1858,1859,1860,1861,1863,1864,1865,1866,1867,1868,1869,1870,1871,1872,1873,1874,1875,1876,1877,1878,1879,1880,1881,1882,1883,1887,1888,1889,1890,1893,1895,1896,1897,1898,1899,1900,1901,1902,1904,1905,1906,1907,1909,1910,1911,1912,1913,1914,1915,1916,1918,1919,1920,1921,1922,1923,1924,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1945,1946,1948,1950,1951,1952,1953,1954,1955,1956,1957,1958,1960,1963,1965,1966,1967,1968,1969,1970,1971,1974,1975,1976,1979,1980,1981,1983,1984,1985,1986,1987,1988,1989,1990,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2006,2008) have mixed types. Specify dtype option on import or set l ...
#   input_df = pd.read_csv("/content/drive/MyDrive/CS 229 Group Project/Data/input_labels_df.csv")

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.model_selection import train_test_split

feature_columns = [col for col in input_df.columns if not col.startswith('y_')]
X = input_df[feature_columns]  # Features
y = input_df[[col for col in input_df.columns if col.startswith('y_')]]

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80981 entries, 0 to 80980
# Columns: 2000 entries, y_verified_purchase_1891129716 to y_rating_B0CDNZ7F2V
# dtypes: bool(223), float64(1000), object(777)
# memory usage: 1.1+ GB

# %%
pip install iterative-stratification
# Out:
# Collecting iterative-stratification
#   Downloading iterative_stratification-0.1.9-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from iterative-stratification) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from iterative-stratification) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from iterative-stratification) (1.5.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->iterative-stratification) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->iterative-stratification) (3.5.0)
# Downloading iterative_stratification-0.1.9-py3-none-any.whl (8.5 kB)
# Installing collected packages: iterative-stratification
# Successfully installed iterative-stratification-0.1.9
